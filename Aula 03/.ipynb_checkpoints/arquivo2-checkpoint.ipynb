# %%
import numpy as np

# %%
np.random.seed(101)
vetor = np.random.randint(0,100,12)
#0 representa o limite inferior
#100 representa o limite superior
#Logo, tenho um intervalo de 0 até 100 (101 valores possíveis)
#12 representa o número de elementos que tenho que selecionar.

# %%
vetor
# Out:
# array([95, 11, 81, 70, 63, 87, 75,  9, 77, 40,  4, 63], dtype=int32)

# %%
vetor2 = np.random.randint(0,100,10)

# %%
vetor2
# Out:
# array([40, 60, 92, 64,  5, 12, 93, 40, 49, 83], dtype=int32)

# %%
vetor.mean()
# Out:
# np.float64(56.25)

# %%
type(vetor)
# Out:
# numpy.ndarray

# %%
vetor2.mean()
# Out:
# np.float64(53.8)

# %%
type(vetor2)
# Out:
# numpy.ndarray
