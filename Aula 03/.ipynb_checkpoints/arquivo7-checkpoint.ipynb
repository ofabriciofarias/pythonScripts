# %%
import numpy as np

# %%
#Criar duas matrizes!
matrizA = np.array([[2,3],[1,4]])
matrizB = np.array([[7,8],[5,6]])

# %%
matrizA
# Out:
# array([[2, 3],
#        [1, 4]])

# %%
matrizB
# Out:
# array([[7, 8],
#        [5, 6]])

# %%
somarAB = matrizA + matrizB

# %%
somarAB
# Out:
# array([[ 9, 11],
#        [ 6, 10]])

# %%
print(somarAB)
# Out:
# [[ 9 11]
#  [ 6 10]]

# %%
somarAB.shape
# Out:
# (2, 2)

# %%
#Outra forma de efetuar a soma de matrizes é usando o numpy
somarAB2 = np.add(matrizA, matrizB)

# %%
somarAB2
# Out:
# array([[ 9, 11],
#        [ 6, 10]])
