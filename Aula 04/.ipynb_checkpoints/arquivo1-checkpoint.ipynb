# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from PIL import Image

# %%
#imagem = Image.open('mia.jpg')
imagem = Image.open('mia.jpg')

# %%
type(imagem)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
imagem_vetor = np.asarray(imagem)

# %%
type(imagem_vetor)
# Out:
# numpy.ndarray

# %%
imagem_vetor.shape
# Out:
# (3024, 4032, 3)

# %%
plt.imshow(imagem_vetor)
plt.show()

# %%
copia_imagem = imagem_vetor.copy()

# %%
type(copia_imagem)
# Out:
# numpy.ndarray

# %%
plt.imshow(copia_imagem)
plt.show()

# %%
#RGB - Vermelho, Verde e Azul

# %%
copia_imagem.shape
# Out:
# (3024, 4032, 3)

# %%
plt.imshow(copia_imagem[:,:,0], cmap = 'magma')
plt.show()

# %%
copia_imagem
# Out:
# array([[[121, 114, 108],
#         [122, 115, 109],
#         [118, 111, 105],
#         ...,
#         [210, 213, 222],
#         [207, 212, 218],
#         [203, 210, 216]],
#
#        [[121, 114, 108],
#         [122, 115, 109],
#         [117, 110, 104],
#         ...,
#         [209, 212, 221],
#         [208, 211, 218],
#         [205, 210, 216]],
#
#        [[122, 115, 109],
#         [123, 116, 110],
#         [122, 115, 109],
#         ...,
#         [210, 210, 222],
#         [207, 210, 219],
#         [206, 209, 218]],
#
#        ...,
#
#        [[184, 193, 202],
#         [184, 193, 202],
#         [184, 193, 202],
#         ...,
#         [166, 150,  52],
#         [168, 152,  56],
#         [172, 158,  61]],
#
#        [[190, 199, 208],
#         [191, 200, 209],
#         [188, 197, 206],
#         ...,
#         [164, 148,  50],
#         [164, 148,  50],
#         [165, 151,  52]],
#
#        [[186, 195, 204],
#         [186, 195, 204],
#         [187, 196, 205],
# ...

# %%
copia_imagem[:,:,0]
# Out:
# array([[121, 122, 118, ..., 210, 207, 203],
#        [121, 122, 117, ..., 209, 208, 205],
#        [122, 123, 122, ..., 210, 207, 206],
#        ...,
#        [184, 184, 184, ..., 166, 168, 172],
#        [190, 191, 188, ..., 164, 164, 165],
#        [186, 186, 187, ..., 168, 165, 160]], dtype=uint8)

# %%
copia_imagem.shape
# Out:
# (3024, 4032, 3)

# %%
copia_imagem[:,:,1] = 100

# %%
plt.imshow(copia_imagem)
plt.show()

# %%
copia_imagem.shape
# Out:
# (3024, 4032, 3)

# %%
copia_imagem
# Out:
# array([[[121, 114, 108],
#         [122, 115, 109],
#         [118, 111, 105],
#         ...,
#         [210, 213, 222],
#         [207, 212, 218],
#         [203, 210, 216]],
#
#        [[121, 100, 108],
#         [122, 100, 109],
#         [117, 100, 104],
#         ...,
#         [209, 100, 221],
#         [208, 100, 218],
#         [205, 100, 216]],
#
#        [[122, 100, 109],
#         [123, 100, 110],
#         [122, 100, 109],
#         ...,
#         [210, 100, 222],
#         [207, 100, 219],
#         [206, 100, 218]],
#
#        ...,
#
#        [[184, 193, 202],
#         [184, 193, 202],
#         [184, 193, 202],
#         ...,
#         [166, 150,  52],
#         [168, 152,  56],
#         [172, 158,  61]],
#
#        [[190, 199, 208],
#         [191, 200, 209],
#         [188, 197, 206],
#         ...,
#         [164, 148,  50],
#         [164, 148,  50],
#         [165, 151,  52]],
#
#        [[186, 195, 204],
#         [186, 195, 204],
#         [187, 196, 205],
# ...

# %%
#Criar uma nova imagem e passar o resultado!
# 1 - A imagem deve estar dividida ao meio, sendo apresentada metade com uma mudança de cor e metade como a original. 
# 2 - Aplicar um filtro degradê na imagem, variando a intensidade das cores na mesma.
# 3 - Crie uma nova imagem e coloque em tons de cinza usando as bibliotecas. Apresente a nova imagem.
# 4 - Troque a ordem do canal das imagens, exemplo de RGB para BGR e apresente em tela as imagens comparando. Uma abaixo da outra.

#Vocês vão compartilhar os resultados em tela! Vai começar aqui a apresentação do aluno e já já eu volto.

#Essa é a atividade para agora. Estou em uma banca. Mas já volto!

#Está quase concluindo aqui! Vocês acabaram a atividade? Podem escerver no chat quando terminarem!
