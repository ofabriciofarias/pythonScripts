# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#pip install opencv-python
import cv2

# %%
imagem = cv2.imread('bentoespock.jpeg')

# %%
type(imagem)
# Out:
# numpy.ndarray

# %%
#BGR - Blue Green Red
imagem.shape
# Out:
# (1280, 960, 3)

# %%
plt.imshow(imagem)
plt.show()

# %%
#Matplotlib trabalha com o RGB
#Open-cv trabalha com BGR
corrige_imagem = cv2.cvtColor(imagem, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(corrige_imagem)
plt.show()

# %%
imagem_escala_cinza = cv2.imread('bentoespock.jpeg', cv2.IMREAD_GRAYSCALE)

# %%
imagem_escala_cinza.shape
# Out:
# (1280, 960)

# %%
imagem_escala_cinza
# Out:
# array([[119, 120, 121, ..., 142, 142, 143],
#        [119, 120, 121, ..., 143, 143, 143],
#        [119, 120, 121, ..., 143, 143, 144],
#        ...,
#        [118, 118, 118, ...,  23,  23,  23],
#        [117, 117, 117, ...,  23,  22,  22],
#        [117, 117, 117, ...,  23,  22,  22]], dtype=uint8)

# %%
#cmap = color map. Indicando a cor que deve aparecer a imagem.
plt.imshow(imagem_escala_cinza, cmap = 'gray')
plt.show()

# %%
plt.imshow(imagem_escala_cinza)
plt.show()

# %%
plt.imshow(imagem_escala_cinza, cmap = 'magma')
plt.show()
