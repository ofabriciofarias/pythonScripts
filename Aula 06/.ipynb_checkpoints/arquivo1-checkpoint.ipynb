# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import cv2

# %%
imagem = cv2.imread('bentoespock.jpeg')

# %%
type(imagem)
# Out:
# numpy.ndarray

# %%
plt.imshow(imagem)
plt.show()

# %%
nova_imagem = cv2.cvtColor(imagem, cv2.COLOR_BGR2RGB)

# %%
nova_imagem.shape
# Out:
# (1280, 960, 3)

# %%
plt.imshow(nova_imagem)
plt.show()

# %%
nova_imagem.shape
# Out:
# (1280, 960, 3)

# %%
imagem.shape
# Out:
# (1280, 960, 3)

# %%
redimensionada_imagem = cv2.resize(nova_imagem, (1280,820))

# %%
plt.imshow(redimensionada_imagem)
plt.show()

# %%
redimensionada_imagem.shape
# Out:
# (820, 1280, 3)

# %%
largura = 0.9
altura = 0.9

# %%
outra_imagem = cv2.resize(nova_imagem, (0,0), nova_imagem, largura, altura)

# %%
plt.imshow(outra_imagem)
plt.show()

# %%
outra_imagem.shape
# Out:
# (1152, 864, 3)

# %%
imagem_girada = cv2.flip(nova_imagem, 0)

# %%
plt.imshow(imagem_girada)
plt.show()

# %%
cv2.imwrite('bento_modificado01.jpg', imagem)
# Out:
# True

# %%
cv2.imwrite('bento_girado01.jpg', imagem_girada)
# Out:
# True

# %%
rotacionada_imagem = cv2.rotate(nova_imagem, cv2.ROTATE_90_COUNTERCLOCKWISE)
plt.imshow(rotacionada_imagem)
plt.show()

# %%
img = plt.figure(figsize=(20,10))
ax = img.add_subplot(111)
ax.imshow(imagem_girada)
plt.show()

# %%
plt.imshow(imagem_girada)
plt.show()
