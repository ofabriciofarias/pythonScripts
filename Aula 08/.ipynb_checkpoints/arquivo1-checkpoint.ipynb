# %%
import numpy as np
import cv2

# %%
#Função
def circulo(event, x, y, flag, param):
    tam_retangulo = 60
    if event == cv2.EVENT_LBUTTONDOWN:
        #cv2.circle(imagem, (x,y), 30, (0,0,255), 5)
        cv2.rectangle(imagem, pt1 = (x,y), pt2 = (x+tam_retangulo,y+tam_retangulo), color = (255,0,0), thickness = 5)
    elif event == cv2.EVENT_RBUTTONDOWN:
        cv2.circle(imagem, (x,y), 100, (255,0,0), 20)
        
cv2.namedWindow(winname = 'minha_imagem')

cv2.setMouseCallback('minha_imagem', circulo)

#Apresentação da imagem com o Open cv
imagem = np.zeros((400,400,3))

while True:
    
    cv2.imshow('minha_imagem', imagem)
    
    if cv2.waitKey(20) & 0xFF == 27:
        break
    
cv2.destroyAllWindows()
