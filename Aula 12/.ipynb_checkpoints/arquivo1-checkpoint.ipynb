# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sum([5,6,2])
# Out:
# 13

# %%
string = 'sum'

# %%
print(string)
# Out:
# sum

# %%
eval(string)
# Out:
# <function sum(iterable, /, start=0)>

# %%
funcaoS = eval(string)

# %%
funcaoS([5,6,2,9])
# Out:
# 22

# %%
mia = cv2.imread('mia.jpg')

# %%
mia
# Out:
# array([[[213, 207, 208],
#         [213, 207, 208],
#         [215, 207, 208],
#         ...,
#         [255, 255, 245],
#         [255, 255, 245],
#         [255, 255, 245]],
#
#        [[215, 209, 210],
#         [214, 208, 209],
#         [216, 208, 209],
#         ...,
#         [255, 255, 245],
#         [255, 255, 245],
#         [255, 255, 245]],
#
#        [[215, 209, 210],
#         [215, 209, 210],
#         [215, 209, 210],
#         ...,
#         [255, 255, 245],
#         [255, 255, 245],
#         [255, 255, 245]],
#
#        ...,
#
#        [[100, 103, 107],
#         [100, 103, 107],
#         [ 99, 102, 106],
#         ...,
#         [142, 148, 155],
#         [141, 147, 154],
#         [140, 146, 153]],
#
#        [[ 94,  97, 101],
#         [ 96,  99, 103],
#         [ 99, 102, 106],
#         ...,
#         [143, 149, 156],
#         [142, 148, 155],
#         [142, 148, 155]],
#
#        [[ 91,  94,  98],
#         [ 96,  99, 103],
#         [100, 103, 107],
#         ...,
#         [142, 148, 155],
#         [143, 149, 156],
#         [144, 150, 157]]], dtype=uint8)

# %% [markdown]
# mia.shape

# %%
mia = cv2.cvtColor(mia, cv2.COLOR_BGR2RGB)
plt.imshow(mia)
plt.show()

# %%
rosto_mia = cv2.imread('rosto_mia.jpg')
rosto_mia = cv2.cvtColor(rosto_mia, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(rosto_mia)
plt.show()

# %%
methods = ['cv2.TM_CCOEFF', 'cv2.TM_CCOEFF_NORMED', 'cv2.TM_CCORR', 
          'cv2.TM_CCORR_NORMED', 'cv2.TM_SQDIFF', 'cv2.TM_SQDIFF_NORMED']

# %%
mia.shape
# Out:
# (3024, 4032, 3)

# %%
mia2 = cv2.imread('mia.jpg')
plt.imshow(mia2[:,:,0])
plt.show()

# %%
rosto_mia.shape
# Out:
# (1577, 1598, 3)

# %%
meu_metodo = eval(methods[5])
res = cv2.matchTemplate(mia, rosto_mia, meu_metodo)

# %%
plt.imshow(res)
plt.show()

# %%
for m in methods:
    
    #criar uma copia da imagem
    copia_mia = mia.copy()
    
    method = eval(m)
    
    #Template Matching
    res = cv2.matchTemplate(copia_mia, rosto_mia, method)
    
    #Pegar os valores minimos e maximos, assim como as localizações minimas e máximas
    min_val, max_val, min_loc, max_loc = cv2.minMaxLoc(res)
    
    if method in [cv2.TM_SQDIFF, cv2.TM_SQDIFF_NORMED]:
        top_esquerdo = min_loc #(x,y)
        
    else:
        top_esquerdo = max_loc
        
    #Definir a forma do retângulo
    altura, largura, canais = rosto_mia.shape
    
    base_direita = (top_esquerdo[0] + largura, top_esquerdo[1] + altura)
    
    cv2.rectangle(mia, top_esquerdo, base_direita, (255,0,0), 20)
    
    #Apresentar as imagens
    plt.subplot(121)
    plt.imshow(res)
    plt.title("Mapa de Calor")
    
    plt.subplot(122)
    plt.imshow(mia)
    plt.title("Detecção")
    
    #Nome do Método
    plt.suptitle(m)
    
    plt.show()
    
    print('\n')

# %%
methods2 = ['cv2.TM_SQDIFF', 'cv2.TM_SQDIFF_NORMED'] 
for m in methods2:
    
    #criar uma copia da imagem
    copia_mia = mia.copy()
    
    method = eval(m)
    
    #Template Matching
    res = cv2.matchTemplate(copia_mia, rosto_mia, method)
    
    #Pegar os valores minimos e maximos, assim como as localizações minimas e máximas
    min_val, max_val, min_loc, max_loc = cv2.minMaxLoc(res)
    
    if method in [cv2.TM_SQDIFF, cv2.TM_SQDIFF_NORMED]:
        top_esquerdo = min_loc #(x,y)
        
    else:
        top_esquerdo = max_loc
        
    #Definir a forma do retângulo
    altura, largura, canais = rosto_mia.shape
    
    base_direita = (top_esquerdo[0] + largura, top_esquerdo[1] + altura)
    
    cv2.rectangle(mia, top_esquerdo, base_direita, (255,0,0), 20)
    
    #Apresentar as imagens
    plt.subplot(121)
    plt.imshow(res)
    plt.title("Mapa de Calor")
    
    plt.subplot(122)
    plt.imshow(mia)
    plt.title("Detecção")
    
    #Nome do Método
    plt.suptitle(m)
    
    plt.show()
    
    print('\n')
