# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
imagem = cv2.imread('mia.jpg')
imagem = cv2.cvtColor(imagem, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(imagem)

# %%
rosto_imagem = cv2.imread('rosto_mia.jpg')
rosto_imagem = cv2.cvtColor(rosto_imagem, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(rosto_imagem)

# %%
rosto_imagem.shape
# Out:
# (1577, 1598, 3)

# %%
imagem.shape
# Out:
# (3024, 4032, 3)

# %%
minha_string = 'sum'

# %%
eval(minha_string)
# Out:
# <function sum(iterable, /, start=0)>

# %%
minha_funcao = eval(minha_string)

# %%
minha_funcao([1,2,3])
# Out:
# 6

# %%
methods = ['cv2.TM_CCOEFF', 'cv2.TM_CCOEFF_NORMED', 'cv2.TM_CCORR', 
          'cv2.TM_CCORR_NORMED', 'cv2.TM_SQDIFF', 'cv2.TM_SQDIFF_NORMED']

# %%
for m in methods:

    #Criar uma copia da imagem
    copia_imagem = imagem.copy()
    
    method = eval(m)
    
    #Templat Matching
    res = cv2.matchTemplate(copia_imagem, rosto_imagem, method)
    
    #Depois pegamos os valores e localizações minimas e máximas para 
    #desenhar o retangulo
    min_val, max_val, min_loc, max_loc = cv2.minMaxLoc(res)
    
    if method in [cv2.TM_SQDIFF, cv2.TM_SQDIFF_NORMED]:
        top_left = min_loc #(x,y)
    else:
        top_left = max_loc
        
        
    #definição da forma do retângulo
    height, width, channels = rosto_imagem.shape
    
    botton_right = (top_left[0] + width, top_left[1] + height)
    
    cv2.rectangle(imagem, top_left, botton_right, (255,0,0), 15)
    
    #Apresentar a imagem
    plt.subplot(121)
    plt.imshow(res)
    plt.title("Mapa de calor do Templat Matching")
    
    plt.subplot(122)
    plt.imshow(imagem)
    plt.title('Detecção do template')
    #Nome do médoto usado
    plt.suptitle(m)
    
    plt.show()
    
    print('\n')
    print('\n')

# %%
meu_metodo = eval('cv2.TM_CCOEFF')
res = cv2.matchTemplate(imagem, rosto_imagem, meu_metodo)

# %%
plt.imshow(res)
