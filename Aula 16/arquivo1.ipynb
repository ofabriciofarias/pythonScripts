# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
barcelona = cv2.imread('barcelona.jpg')
barcelona = cv2.cvtColor(barcelona, cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(barcelona, cmap= 'gray')
plt.show()

# %%
turma = cv2.imread('turma.jpg')
turma = cv2.cvtColor(turma, cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(turma, cmap = 'gray')
plt.show()

# %%
face_cascade = cv2.CascadeClassifier('data/haarcascades/haarcascade_licence_plate_rus_16stages.xml')

# %%
def face_detector(imagem):
    cont = 0
    face_imagem = imagem.copy()
    
    face_retangulo = face_cascade.detectMultiScale(face_imagem, scaleFactor = 1.2, minNeighbors = 5)
    
    for (x,y,w,h) in face_retangulo:
        cv2.rectangle(face_imagem, (x,y), (x+w, y+h), (255,0,0), 10)
        cont = cont + 1
        
    print(cont)
    return face_imagem

# %%
resultado = face_detector(barcelona)
plt.imshow(resultado, cmap = 'gray')
plt.show()
# Out:
# 1
