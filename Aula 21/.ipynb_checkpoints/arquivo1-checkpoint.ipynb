# %%
from ultralytics import YOLO

# 1. Load a model
# 'yolo11n.pt' is the Nano model (fastest, lightest).
# It will automatically download the weights file on the first run.
model = YOLO('yolo11n.pt') 

# 2. Run inference on a source
# You can use a local image path, a URL, or '0' for webcam.
source = 'https://ultralytics.com/images/bus.jpg' 

# 3. Predict
results = model(source)

# 4. Process results
for result in results:
    boxes = result.boxes  # Boxes object for bbox outputs
    result.show()         # Display result window
    result.save(filename='result.jpg') # Save to disk
# Out:
# ...
# image 1/1 C:\Users\fabri\Documents\pythonScripts\Aula 21\zidane.jpg: 384x640 2 persons, 1 tie, 35.5ms
# Speed: 2.3ms preprocess, 35.5ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
